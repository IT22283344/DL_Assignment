# %% [markdown]
# <a href="https://colab.research.google.com/github/IT22283344/DL_Assignment/blob/ravindu/DL_assignmnet.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Mount Google Drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import os
import zipfile
import numpy as np
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import matplotlib.pyplot as plt
from sklearn.metrics import classification_report, confusion_matrix
import seaborn as sns

# Check if GPU is available
print("GPU Available:", tf.config.list_physical_devices('GPU'))
# Out:
# GPU Available: []

# %%
# Extract the dataset (modify the path according to your file location)
dataset_path = '/content/drive/MyDrive/SE4050/DATASET.zip'
extract_path = '/content/dataset'

with zipfile.ZipFile(dataset_path, 'r') as zip_ref:
    zip_ref.extractall(extract_path)

print("Dataset extracted successfully!")
# Out:
# Dataset extracted successfully!

# %%
# Check the dataset structure
dataset_dir = '/content/dataset'
print("Contents of dataset directory:")
for root, dirs, files in os.walk(dataset_dir):
    level = root.replace(dataset_dir, '').count(os.sep)
    indent = ' ' * 2 * level
    print(f'{indent}{os.path.basename(root)}/')
    subindent = ' ' * 2 * (level + 1)
    for file in files[:5]:  # Show first 5 files
        print(f'{subindent}{file}')
    if len(files) > 5:
        print(f'{subindent}... and {len(files) - 5} more files')
# Out:
# Contents of dataset directory:
# dataset/
#   DATASET/
#     .DS_Store
#     TEST/
#       O/
#         O_12757.jpg
#         O_13644.jpg
#         O_12686.jpg
#         O_13730.jpg
#         O_13780.jpg
#         ... and 1396 more files
#       R/
#         R_10977.jpg
#         R_11048.jpg
#         R_10352.jpg
#         R_10566.jpg
#         R_10587.jpg
#         ... and 1107 more files
#     TRAIN/
#       O/
#         O_8817.jpg
#         O_9907.jpg
#         O_12473.jpg
#         O_10798.jpg
#         O_12400.jpg
#         ... and 12560 more files
#       R/
#         R_5239.jpg
#         R_2831.jpg
#         R_4248.jpg
#         R_2953.jpg
#         R_845.jpg
#         ... and 9994 more files
#   __MACOSX/
#     ._DATASET
#     DATASET/
#       ._.DS_Store
#       ._TRAIN
#       ._TEST
#       TEST/
#         ._O
#         ._R
#         O/
#           ._O_13384.jpg
#           ._O_13769.jpg
#           ._O_12763.jpg
#           ._O_13786.jpg
#           ._O_12696.jpg
# ...

# %%
# Set up paths and parameters
IMG_HEIGHT = 224
IMG_WIDTH = 224
BATCH_SIZE = 32
EPOCHS = 25

# Data augmentation and preprocessing
train_datagen = ImageDataGenerator(
    rescale=1./255,
    rotation_range=20,
    width_shift_range=0.2,
    height_shift_range=0.2,
    horizontal_flip=True,
    zoom_range=0.2,
    shear_range=0.2,
    fill_mode='nearest',
    validation_split=0.2  # 80% training, 20% validation
)

test_datagen = ImageDataGenerator(rescale=1./255)
